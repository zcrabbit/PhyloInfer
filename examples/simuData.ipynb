# %% [markdown]
# # An example on simulated data

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# load modules
import phyloinfer as pinf
import numpy as np

# %%
# simulate Data
pden = np.array([.25,.25,.25,.25])

# decompose the rate matrix (JC model)
D, U, U_inv, rate_matrix = pinf.rateM.decompJC()

# sample a random tree from the prior
ntips = 50
true_tree = pinf.tree.create(ntips, branch='random')

data = pinf.data.treeSimu(true_tree, D, U, U_inv, pden, 1000)

# %%
# you may want to take a look of the negative log-posterior and log-likelihood of the true tree
L = pinf.Loglikelihood.initialCLV(data)
true_branch = pinf.branch.get(true_tree)
print "The negative log-posterior of the true tree: {}".format(pinf.Logposterior.Logpost(true_tree, true_branch, D, U, U_inv, pden, L))
print "The log-likelihood of the true tree: {}".format(pinf.Loglikelihood.phyloLoglikelihood(true_tree, true_branch, D, U, U_inv, pden, L))
# Out:
# The negative log-posterior of the true tree: 33121.9813127
# The log-likelihood of the true tree: -33247.2273288

# %%
# sample a starting tree from the prior
init_tree = pinf.tree.create(ntips, branch='random')

# %%
# you may also want to take a look of the negative log-posterior and log-likelihood of the initial tree
init_branch = pinf.branch.get(init_tree)
print "The negative log-posterior of the init tree: {}".format(pinf.Logposterior.Logpost(init_tree, init_branch, D, U, U_inv, pden, L))
print "The log-likelihood of the init tree: {}".format(pinf.Loglikelihood.phyloLoglikelihood(init_tree, init_branch, D, U, U_inv, pden, L))
# Out:
# The negative log-posterior of the init tree: 51744.1795151
# The log-likelihood of the init tree: -51879.4412823

# %%
# now run ppHMC to sample from the posterior
samp_res = pinf.phmc.hmc(init_tree, init_branch, (pden, 1.0), data, 100, 0.001, 100,
                         subModel='JC', surrogate=True, burnin_frac=0.2, delta=0.002,
                         adap_stepsz_rate = 0.4, monitor_event=True, printfreq=50)
# Out:
# NNI attempts: 40
# Ref attempts: 57
# 1 iteration: current Loglikelihood = -43009.062893
# NNI attempts: 29
# Ref attempts: 42
# 2 iteration: current Loglikelihood = -43009.062893
# NNI attempts: 19
# Ref attempts: 30
# 3 iteration: current Loglikelihood = -43009.062893
# NNI attempts: 17
# Ref attempts: 25
# 4 iteration: current Loglikelihood = -43009.062893
# NNI attempts: 2
# Ref attempts: 2
# 5 iteration: current Loglikelihood = -42895.3322432
# NNI attempts: 38
# Ref attempts: 61
# 6 iteration: current Loglikelihood = -41214.8033877
# NNI attempts: 42
# Ref attempts: 61
# 7 iteration: current Loglikelihood = -39984.115028
# NNI attempts: 7
# Ref attempts: 9
# 8 iteration: current Loglikelihood = -39570.2896162
# NNI attempts: 18
# Ref attempts: 26
# 9 iteration: current Loglikelihood = -39229.56605
# NNI attempts: 25
# Ref attempts: 46
# 10 iteration: current Loglikelihood = -38688.7040482
# NNI attempts: 20
# Ref attempts: 35
# 11 iteration: current Loglikelihood = -38292.8073782
# NNI attempts: 35
# Ref attempts: 57
# 12 iteration: current Loglikelihood = -38292.8073782
# NNI attempts: 23
# Ref attempts: 38
# 13 iteration: current Loglikelihood = -38292.8073782
# NNI attempts: 1
# Ref attempts: 4
# 14 iteration: current Loglikelihood = -38170.6509101
# NNI attempts: 15
# Ref attempts: 33
# 15 iteration: current Loglikelihood = -37880.8190754
# NNI attempts: 21
# Ref attempts: 46
# 16 iteration: current Loglikelihood = -37766.6301993
# NNI attempts: 19
# Ref attempts: 34
# 17 iteration: current Loglikelihood = -37508.9147618
# NNI attempts: 27
# Ref attempts: 46
# 18 iteration: current Loglikelihood = -37290.1774937
# NNI attempts: 3
# Ref attempts: 8
# 19 iteration: current Loglikelihood = -37190.8319876
# NNI attempts: 7
# Ref attempts: 8
# 20 iteration: current Loglikelihood = -37160.9145574
# NNI attempts: 20
# Ref attempts: 39
# 21 iteration: current Loglikelihood = -37160.9145574
# NNI attempts: 20
# Ref attempts: 34
# 22 iteration: current Loglikelihood = -37160.9145574
# NNI attempts: 10
# Ref attempts: 30
# 23 iteration: current Loglikelihood = -37160.9145574
# NNI attempts: 18
# Ref attempts: 36
# 24 iteration: current Loglikelihood = -37095.1197563
# NNI attempts: 4
# Ref attempts: 12
# 25 iteration: current Loglikelihood = -37095.1197563
# NNI attempts: 5
# Ref attempts: 18
# 26 iteration: current Loglikelihood = -37053.8327835
# NNI attempts: 6
# Ref attempts: 25
# 27 iteration: current Loglikelihood = -37053.8203127
# NNI attempts: 2
# Ref attempts: 14
# 28 iteration: current Loglikelihood = -37015.1021757
# NNI attempts: 0
# Ref attempts: 1
# 29 iteration: current Loglikelihood = -37015.1021757
# NNI attempts: 12
# Ref attempts: 20
# 30 iteration: current Loglikelihood = -37015.1021757
# NNI attempts: 1
# Ref attempts: 6
# 31 iteration: current Loglikelihood = -36998.7333151
# NNI attempts: 1
# Ref attempts: 6
# 32 iteration: current Loglikelihood = -36996.425444
# NNI attempts: 2
# Ref attempts: 5
# 33 iteration: current Loglikelihood = -36991.91162
# NNI attempts: 2
# Ref attempts: 8
# 34 iteration: current Loglikelihood = -36987.710964
# NNI attempts: 13
# Ref attempts: 39
# 35 iteration: current Loglikelihood = -36925.5533538
# NNI attempts: 0
# Ref attempts: 1
# 36 iteration: current Loglikelihood = -36925.3988494
# NNI attempts: 11
# Ref attempts: 18
# 37 iteration: current Loglikelihood = -36925.3988494
# NNI attempts: 4
# Ref attempts: 7
# 38 iteration: current Loglikelihood = -36908.9647367
# NNI attempts: 4
# Ref attempts: 10
# 39 iteration: current Loglikelihood = -36901.0983101
# NNI attempts: 3
# Ref attempts: 4
# 40 iteration: current Loglikelihood = -36893.3905571
# NNI attempts: 15
# Ref attempts: 22
# 41 iteration: current Loglikelihood = -36860.6810208
# NNI attempts: 24
# Ref attempts: 38
# 42 iteration: current Loglikelihood = -36860.6810208
# NNI attempts: 16
# Ref attempts: 27
# 43 iteration: current Loglikelihood = -36721.3483174
# NNI attempts: 11
# Ref attempts: 25
# 44 iteration: current Loglikelihood = -36055.5363722
# NNI attempts: 20
# Ref attempts: 42
# 45 iteration: current Loglikelihood = -36055.5363722
# NNI attempts: 20
# Ref attempts: 36
# 46 iteration: current Loglikelihood = -36055.5363722
# NNI attempts: 12
# Ref attempts: 28
# 47 iteration: current Loglikelihood = -36000.1257317
# NNI attempts: 7
# Ref attempts: 19
# 48 iteration: current Loglikelihood = -35841.0074864
# NNI attempts: 3
# Ref attempts: 7
# 49 iteration: current Loglikelihood = -35675.5510679
# NNI attempts: 1
# Ref attempts: 8
# 50 iteration: current Loglikelihood = -35562.3822277
#
# ######   50 iterations completed; acceptance rate: 0.7
#
# NNI attempts: 0
# Ref attempts: 2
# 51 iteration: current Loglikelihood = -35552.4224852
# NNI attempts: 0
# Ref attempts: 2
# 52 iteration: current Loglikelihood = -35516.3466112
# NNI attempts: 4
# Ref attempts: 11
# 53 iteration: current Loglikelihood = -35399.0842092
# NNI attempts: 10
# Ref attempts: 22
# 54 iteration: current Loglikelihood = -35399.0842092
# NNI attempts: 4
# Ref attempts: 15
# 55 iteration: current Loglikelihood = -35240.5330163
# NNI attempts: 18
# Ref attempts: 34
# 56 iteration: current Loglikelihood = -35240.5330163
# NNI attempts: 0
# Ref attempts: 1
# 57 iteration: current Loglikelihood = -35228.5490008
# NNI attempts: 1
# Ref attempts: 2
# 58 iteration: current Loglikelihood = -35219.2526375
# NNI attempts: 12
# Ref attempts: 15
# 59 iteration: current Loglikelihood = -35219.2526375
# NNI attempts: 11
# Ref attempts: 16
# 60 iteration: current Loglikelihood = -35180.8981476
# NNI attempts: 36
# Ref attempts: 53
# 61 iteration: current Loglikelihood = -35180.8981476
# NNI attempts: 23
# Ref attempts: 37
# 62 iteration: current Loglikelihood = -35180.8981476
# NNI attempts: 11
# Ref attempts: 23
# 63 iteration: current Loglikelihood = -35111.8283404
# NNI attempts: 27
# Ref attempts: 55
# 64 iteration: current Loglikelihood = -34618.8484578
# NNI attempts: 31
# Ref attempts: 54
# 65 iteration: current Loglikelihood = -34247.4326713
# NNI attempts: 17
# Ref attempts: 35
# 66 iteration: current Loglikelihood = -34247.4326713
# NNI attempts: 27
# Ref attempts: 53
# 67 iteration: current Loglikelihood = -34247.4326713
# NNI attempts: 28
# Ref attempts: 48
# 68 iteration: current Loglikelihood = -33649.5393973
# NNI attempts: 6
# Ref attempts: 19
# 69 iteration: current Loglikelihood = -33383.8560451
# NNI attempts: 14
# Ref attempts: 39
# 70 iteration: current Loglikelihood = -33304.3238382
# NNI attempts: 15
# Ref attempts: 44
# 71 iteration: current Loglikelihood = -33304.3238382
# NNI attempts: 0
# Ref attempts: 6
# 72 iteration: current Loglikelihood = -33304.3238382
# NNI attempts: 7
# Ref attempts: 24
# 73 iteration: current Loglikelihood = -33254.8441252
# NNI attempts: 4
# Ref attempts: 14
# 74 iteration: current Loglikelihood = -33248.1604678
# NNI attempts: 6
# Ref attempts: 16
# 75 iteration: current Loglikelihood = -33245.6902869
# NNI attempts: 4
# Ref attempts: 11
# 76 iteration: current Loglikelihood = -33247.0526213
# NNI attempts: 6
# Ref attempts: 18
# 77 iteration: current Loglikelihood = -33242.0029527
# NNI attempts: 12
# Ref attempts: 32
# 78 iteration: current Loglikelihood = -33234.5079703
# NNI attempts: 6
# Ref attempts: 36
# 79 iteration: current Loglikelihood = -33235.1570781
# NNI attempts: 3
# Ref attempts: 10
# 80 iteration: current Loglikelihood = -33247.9290984
# NNI attempts: 1
# Ref attempts: 8
# 81 iteration: current Loglikelihood = -33242.64268
# NNI attempts: 16
# Ref attempts: 35
# 82 iteration: current Loglikelihood = -33260.7474717
# NNI attempts: 9
# Ref attempts: 27
# 83 iteration: current Loglikelihood = -33260.7474717
# NNI attempts: 11
# Ref attempts: 28
# 84 iteration: current Loglikelihood = -33259.3035255
# NNI attempts: 6
# Ref attempts: 32
# 85 iteration: current Loglikelihood = -33256.909684
# NNI attempts: 12
# Ref attempts: 24
# 86 iteration: current Loglikelihood = -33248.912743
# NNI attempts: 25
# Ref attempts: 41
# 87 iteration: current Loglikelihood = -33262.9429961
# NNI attempts: 22
# Ref attempts: 44
# 88 iteration: current Loglikelihood = -33263.7028641
# NNI attempts: 28
# Ref attempts: 49
# 89 iteration: current Loglikelihood = -33258.775668
# NNI attempts: 4
# Ref attempts: 7
# 90 iteration: current Loglikelihood = -33248.400673
# NNI attempts: 17
# Ref attempts: 25
# 91 iteration: current Loglikelihood = -33251.5307494
# NNI attempts: 3
# Ref attempts: 7
# 92 iteration: current Loglikelihood = -33246.7516808
# NNI attempts: 10
# Ref attempts: 28
# 93 iteration: current Loglikelihood = -33254.892734
# NNI attempts: 15
# Ref attempts: 30
# 94 iteration: current Loglikelihood = -33249.9837973
# NNI attempts: 5
# Ref attempts: 12
# 95 iteration: current Loglikelihood = -33244.641245
# NNI attempts: 8
# Ref attempts: 10
# 96 iteration: current Loglikelihood = -33246.1718134
# NNI attempts: 5
# Ref attempts: 11
# 97 iteration: current Loglikelihood = -33238.8708653
# NNI attempts: 10
# Ref attempts: 17
# 98 iteration: current Loglikelihood = -33245.4200646
# NNI attempts: 6
# Ref attempts: 9
# 99 iteration: current Loglikelihood = -33252.4973933
# NNI attempts: 2
# Ref attempts: 5
# 100 iteration: current Loglikelihood = -33249.134183
#
# ######   100 iterations completed; acceptance rate: 0.8
#
# Overall acceptance rate: 0.75
