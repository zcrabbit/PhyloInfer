# %% [markdown]
# # An example on simulated data

# %%
import sys, os
sys.path.insert(0,"..")

# %%
sys.path
# Out:
# ['..',
#  '',
#  '/Users/chengzhang/anaconda2/lib/python27.zip',
#  '/Users/chengzhang/anaconda2/lib/python2.7',
#  '/Users/chengzhang/anaconda2/lib/python2.7/plat-darwin',
#  '/Users/chengzhang/anaconda2/lib/python2.7/plat-mac',
#  '/Users/chengzhang/anaconda2/lib/python2.7/plat-mac/lib-scriptpackages',
#  '/Users/chengzhang/anaconda2/lib/python2.7/lib-tk',
#  '/Users/chengzhang/anaconda2/lib/python2.7/lib-old',
#  '/Users/chengzhang/anaconda2/lib/python2.7/lib-dynload',
#  '/Users/chengzhang/anaconda2/lib/python2.7/site-packages/Sphinx-1.3.5-py2.7.egg',
#  '/Users/chengzhang/anaconda2/lib/python2.7/site-packages/ete3-3.0.0b36-py3.5.egg',
#  '/Users/chengzhang/anaconda2/lib/python2.7/site-packages/setuptools-20.3-py2.7.egg',
#  '/Users/chengzhang/anaconda2/lib/python2.7/site-packages',
#  '/Users/chengzhang/anaconda2/lib/python2.7/site-packages/aeosa',
#  '/Users/chengzhang/anaconda2/lib/python2.7/site-packages/IPython/extensions',
#  '/Users/chengzhang/.ipython']

# %%
# load modules
import phyloinfer as pinf
import numpy as np

# %%
# simulate Data
pden = np.array([.1,.2,.3,.4])
kappa = 2

# decompose the rate matrix (HKY model)
D, U, beta, rate_matrix = pinf.rateM.decompHKY(pden, kappa)

# sample a random tree from the prior
ntips = 50
true_tree = pinf.Tree()
true_tree.populate(ntips)
true_tree.unroot()
pinf.tree.init(true_tree, branch='random')

data = pinf.data.treeSimu(true_tree, D, U, beta, pden, 1000)

# %%
# you may want to take a look of the negative log-posterior and log-likelihood of the true tree
L = pinf.Loglikelihood.initialCLV(true_tree, data)
true_branch = pinf.branch.get(true_tree)
print "The negative log-posterior of the true tree: {}".format(pinf.Logposterior.Logpost(true_tree, true_branch, D, U, beta, pden, L))
print "The log-likelihood of the true tree: {}".format(pinf.Loglikelihood.phyloLoglikelihood(true_tree, true_branch, D, U, beta, pden, L))
# Out:
# The negative log-posterior of the true tree: 31127.3565867
# The log-likelihood of the true tree: -31255.449606

# %%
# sample a starting tree from the prior
init_tree = pinf.Tree()
init_tree.populate(ntips)
init_tree.unroot()
pinf.tree.init(init_tree, branch='random')

# %%
# you may also want to take a look of the negative log-posterior and log-likelihood of the initial tree
init_branch = pinf.branch.get(init_tree)
print "The negative log-posterior of the init tree: {}".format(pinf.Logposterior.Logpost(init_tree, init_branch, D, U, beta, pden, L))
print "The log-likelihood of the init tree: {}".format(pinf.Loglikelihood.phyloLoglikelihood(init_tree, init_branch, D, U, beta, pden, L))
# Out:
# The negative log-posterior of the init tree: 45786.8261624
# The log-likelihood of the init tree: -45906.8059006

# %%
# now run ppHMC to sample from the posterior
samp_res = pinf.phmc.hmc(init_tree, init_branch, (pden,kappa), data, 100, 0.0005, 100,
                         subModel='HKY', burned=0.2, adap_stepsz_rate = 0.6)
# Out:
# NNI attempts: 0
# Ref attempts: 0
# 1 iteration: current Loglikelihood = -40149.6995587
# NNI attempts: 7
# Ref attempts: 9
# 2 iteration: current Loglikelihood = -38698.9112955
# NNI attempts: 7
# Ref attempts: 7
# 3 iteration: current Loglikelihood = -38698.9112955
# NNI attempts: 9
# Ref attempts: 9
# 4 iteration: current Loglikelihood = -37970.4919548
# NNI attempts: 11
# Ref attempts: 11
# 5 iteration: current Loglikelihood = -37446.2075358
# NNI attempts: 4
# Ref attempts: 4
# 6 iteration: current Loglikelihood = -37339.3862403
# NNI attempts: 9
# Ref attempts: 9
# 7 iteration: current Loglikelihood = -37339.3862403
# NNI attempts: 11
# Ref attempts: 11
# 8 iteration: current Loglikelihood = -36505.5563067
# NNI attempts: 13
# Ref attempts: 13
# 9 iteration: current Loglikelihood = -35582.9147105
# NNI attempts: 14
# Ref attempts: 15
# 10 iteration: current Loglikelihood = -34887.1364546
# NNI attempts: 12
# Ref attempts: 12
# 11 iteration: current Loglikelihood = -34182.2857885
# NNI attempts: 1
# Ref attempts: 1
# 12 iteration: current Loglikelihood = -34057.4353101
# NNI attempts: 2
# Ref attempts: 3
# 13 iteration: current Loglikelihood = -33802.2121653
# NNI attempts: 4
# Ref attempts: 4
# 14 iteration: current Loglikelihood = -33586.8813511
# NNI attempts: 8
# Ref attempts: 10
# 15 iteration: current Loglikelihood = -33586.8813511
# NNI attempts: 17
# Ref attempts: 20
# 16 iteration: current Loglikelihood = -33586.8813511
# NNI attempts: 16
# Ref attempts: 20
# 17 iteration: current Loglikelihood = -33315.3649295
# NNI attempts: 12
# Ref attempts: 13
# 18 iteration: current Loglikelihood = -33315.3649295
# NNI attempts: 16
# Ref attempts: 18
# 19 iteration: current Loglikelihood = -33315.3649295
# NNI attempts: 14
# Ref attempts: 17
# 20 iteration: current Loglikelihood = -33315.3649295
# 20 iterations completed; acceptance rate: 0.65
# NNI attempts: 21
# Ref attempts: 27
# 21 iteration: current Loglikelihood = -33315.3649295
# NNI attempts: 5
# Ref attempts: 5
# 22 iteration: current Loglikelihood = -33163.7686138
# NNI attempts: 2
# Ref attempts: 2
# 23 iteration: current Loglikelihood = -33104.1380251
# NNI attempts: 11
# Ref attempts: 11
# 24 iteration: current Loglikelihood = -32966.0361388
# NNI attempts: 7
# Ref attempts: 7
# 25 iteration: current Loglikelihood = -32864.7699246
# NNI attempts: 12
# Ref attempts: 12
# 26 iteration: current Loglikelihood = -32735.4354424
# NNI attempts: 6
# Ref attempts: 6
# 27 iteration: current Loglikelihood = -32559.6988259
# NNI attempts: 4
# Ref attempts: 4
# 28 iteration: current Loglikelihood = -32559.6988259
# NNI attempts: 10
# Ref attempts: 12
# 29 iteration: current Loglikelihood = -32200.3716281
# NNI attempts: 5
# Ref attempts: 6
# 30 iteration: current Loglikelihood = -32107.8840552
# NNI attempts: 2
# Ref attempts: 2
# 31 iteration: current Loglikelihood = -32079.3742708
# NNI attempts: 0
# Ref attempts: 0
# 32 iteration: current Loglikelihood = -32080.2493007
# NNI attempts: 7
# Ref attempts: 9
# 33 iteration: current Loglikelihood = -31933.6384926
# NNI attempts: 3
# Ref attempts: 3
# 34 iteration: current Loglikelihood = -31839.5413327
# NNI attempts: 4
# Ref attempts: 5
# 35 iteration: current Loglikelihood = -31768.0564464
# NNI attempts: 10
# Ref attempts: 12
# 36 iteration: current Loglikelihood = -31650.6208912
# NNI attempts: 5
# Ref attempts: 6
# 37 iteration: current Loglikelihood = -31650.6208912
# NNI attempts: 8
# Ref attempts: 10
# 38 iteration: current Loglikelihood = -31416.7050844
# NNI attempts: 6
# Ref attempts: 6
# 39 iteration: current Loglikelihood = -31423.0230743
# NNI attempts: 2
# Ref attempts: 2
# 40 iteration: current Loglikelihood = -31404.2278083
# 40 iterations completed; acceptance rate: 0.85
# NNI attempts: 1
# Ref attempts: 1
# 41 iteration: current Loglikelihood = -31404.2497726
# NNI attempts: 6
# Ref attempts: 8
# 42 iteration: current Loglikelihood = -31404.2497726
# NNI attempts: 7
# Ref attempts: 8
# 43 iteration: current Loglikelihood = -31406.9781096
# NNI attempts: 3
# Ref attempts: 3
# 44 iteration: current Loglikelihood = -31412.1960178
# NNI attempts: 7
# Ref attempts: 7
# 45 iteration: current Loglikelihood = -31359.8501435
# NNI attempts: 0
# Ref attempts: 0
# 46 iteration: current Loglikelihood = -31355.890806
# NNI attempts: 0
# Ref attempts: 0
# 47 iteration: current Loglikelihood = -31353.8028495
# NNI attempts: 5
# Ref attempts: 5
# 48 iteration: current Loglikelihood = -31293.667075
# NNI attempts: 3
# Ref attempts: 4
# 49 iteration: current Loglikelihood = -31289.8445932
# NNI attempts: 5
# Ref attempts: 6
# 50 iteration: current Loglikelihood = -31283.8407744
# NNI attempts: 3
# Ref attempts: 3
# 51 iteration: current Loglikelihood = -31284.4265085
# NNI attempts: 7
# Ref attempts: 9
# 52 iteration: current Loglikelihood = -31277.614023
# NNI attempts: 2
# Ref attempts: 2
# 53 iteration: current Loglikelihood = -31277.614023
# NNI attempts: 3
# Ref attempts: 4
# 54 iteration: current Loglikelihood = -31259.6831295
# NNI attempts: 4
# Ref attempts: 5
# 55 iteration: current Loglikelihood = -31268.0998172
# NNI attempts: 3
# Ref attempts: 5
# 56 iteration: current Loglikelihood = -31268.0998172
# NNI attempts: 0
# Ref attempts: 0
# 57 iteration: current Loglikelihood = -31260.9666281
# NNI attempts: 0
# Ref attempts: 0
# 58 iteration: current Loglikelihood = -31255.5696559
# NNI attempts: 1
# Ref attempts: 1
# 59 iteration: current Loglikelihood = -31250.2553482
# NNI attempts: 3
# Ref attempts: 3
# 60 iteration: current Loglikelihood = -31260.0318791
# 60 iterations completed; acceptance rate: 0.85
# NNI attempts: 3
# Ref attempts: 4
# 61 iteration: current Loglikelihood = -31260.0318791
# NNI attempts: 5
# Ref attempts: 7
# 62 iteration: current Loglikelihood = -31261.8511917
# NNI attempts: 5
# Ref attempts: 5
# 63 iteration: current Loglikelihood = -31263.6627244
# NNI attempts: 4
# Ref attempts: 4
# 64 iteration: current Loglikelihood = -31260.746441
# NNI attempts: 6
# Ref attempts: 6
# 65 iteration: current Loglikelihood = -31251.8354735
# NNI attempts: 0
# Ref attempts: 0
# 66 iteration: current Loglikelihood = -31247.4721715
# NNI attempts: 1
# Ref attempts: 1
# 67 iteration: current Loglikelihood = -31257.0217947
# NNI attempts: 1
# Ref attempts: 1
# 68 iteration: current Loglikelihood = -31267.4517667
# NNI attempts: 0
# Ref attempts: 0
# 69 iteration: current Loglikelihood = -31264.085775
# NNI attempts: 1
# Ref attempts: 1
# 70 iteration: current Loglikelihood = -31255.8709501
# NNI attempts: 2
# Ref attempts: 2
# 71 iteration: current Loglikelihood = -31252.7986169
# NNI attempts: 3
# Ref attempts: 3
# 72 iteration: current Loglikelihood = -31254.707694
# NNI attempts: 0
# Ref attempts: 0
# 73 iteration: current Loglikelihood = -31259.2631208
# NNI attempts: 2
# Ref attempts: 2
# 74 iteration: current Loglikelihood = -31255.8852614
# NNI attempts: 1
# Ref attempts: 1
# 75 iteration: current Loglikelihood = -31257.563415
# NNI attempts: 1
# Ref attempts: 3
# 76 iteration: current Loglikelihood = -31258.6873914
# NNI attempts: 0
# Ref attempts: 0
# 77 iteration: current Loglikelihood = -31258.9971467
# NNI attempts: 2
# Ref attempts: 3
# 78 iteration: current Loglikelihood = -31268.2413357
# NNI attempts: 4
# Ref attempts: 5
# 79 iteration: current Loglikelihood = -31273.5621996
# NNI attempts: 3
# Ref attempts: 4
# 80 iteration: current Loglikelihood = -31257.3267223
# 80 iterations completed; acceptance rate: 0.95
# NNI attempts: 6
# Ref attempts: 10
# 81 iteration: current Loglikelihood = -31257.3267223
# NNI attempts: 7
# Ref attempts: 10
# 82 iteration: current Loglikelihood = -31257.3267223
# NNI attempts: 0
# Ref attempts: 0
# 83 iteration: current Loglikelihood = -31250.3479603
# NNI attempts: 6
# Ref attempts: 6
# 84 iteration: current Loglikelihood = -31259.1942396
# NNI attempts: 6
# Ref attempts: 7
# 85 iteration: current Loglikelihood = -31263.8719809
# NNI attempts: 0
# Ref attempts: 0
# 86 iteration: current Loglikelihood = -31259.0256077
# NNI attempts: 2
# Ref attempts: 2
# 87 iteration: current Loglikelihood = -31244.5966691
# NNI attempts: 3
# Ref attempts: 3
# 88 iteration: current Loglikelihood = -31257.6154575
# NNI attempts: 5
# Ref attempts: 6
# 89 iteration: current Loglikelihood = -31245.2497556
# NNI attempts: 4
# Ref attempts: 4
# 90 iteration: current Loglikelihood = -31254.815446
# NNI attempts: 0
# Ref attempts: 0
# 91 iteration: current Loglikelihood = -31253.464901
# NNI attempts: 5
# Ref attempts: 5
# 92 iteration: current Loglikelihood = -31252.4127171
# NNI attempts: 0
# Ref attempts: 0
# 93 iteration: current Loglikelihood = -31251.7449169
# NNI attempts: 4
# Ref attempts: 4
# 94 iteration: current Loglikelihood = -31247.4215887
# NNI attempts: 3
# Ref attempts: 3
# 95 iteration: current Loglikelihood = -31254.0177877
# NNI attempts: 5
# Ref attempts: 5
# 96 iteration: current Loglikelihood = -31248.5026822
# NNI attempts: 5
# Ref attempts: 7
# 97 iteration: current Loglikelihood = -31249.7686511
# NNI attempts: 8
# Ref attempts: 8
# 98 iteration: current Loglikelihood = -31249.1325477
# NNI attempts: 1
# Ref attempts: 1
# 99 iteration: current Loglikelihood = -31257.4202848
# NNI attempts: 0
# Ref attempts: 0
# 100 iteration: current Loglikelihood = -31247.7696789
# 100 iterations completed; acceptance rate: 0.9
# Overall acceptance rate: 0.8875
