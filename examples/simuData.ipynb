# %% [markdown]
# # An example on simulated data

# %%
import sys, os
sys.path.insert(0,"..")

# %%
# load modules
import phyloinfer as pinf
import numpy as np

# %%
# simulate Data
pden = np.array([.25,.25,.25,.25])

# decompose the rate matrix (JC model)
D, U, beta, rate_matrix = pinf.rateM.decompJC()

# sample a random tree from the prior
ntips = 50
true_tree = pinf.Tree()
true_tree.populate(ntips)
true_tree.unroot()
pinf.tree.init(true_tree, branch='random')

data = pinf.data.treeSimu(true_tree, D, U, beta, pden, 1000)

# %%
# you may want to take a look of the negative log-posterior and log-likelihood of the true tree
L = pinf.Loglikelihood.initialCLV(data)
true_branch = pinf.branch.get(true_tree)
print "The negative log-posterior of the true tree: {}".format(pinf.Logposterior.Logpost(true_tree, true_branch, D, U, beta, pden, L))
print "The log-likelihood of the true tree: {}".format(pinf.Loglikelihood.phyloLoglikelihood(true_tree, true_branch, D, U, beta, pden, L))
# Out:
# The negative log-posterior of the true tree: 36036.2164593
# The log-likelihood of the true tree: -36154.088912

# %%
# sample a starting tree from the prior
init_tree = pinf.Tree()
init_tree.populate(ntips)
init_tree.unroot()
pinf.tree.init(init_tree, branch='random')

# %%
# you may also want to take a look of the negative log-posterior and log-likelihood of the initial tree
init_branch = pinf.branch.get(init_tree)
print "The negative log-posterior of the init tree: {}".format(pinf.Logposterior.Logpost(init_tree, init_branch, D, U, beta, pden, L))
print "The log-likelihood of the init tree: {}".format(pinf.Loglikelihood.phyloLoglikelihood(init_tree, init_branch, D, U, beta, pden, L))
# Out:
# The negative log-posterior of the init tree: 49031.1900312
# The log-likelihood of the init tree: -49165.3370846

# %%
# now run ppHMC to sample from the posterior
samp_res = pinf.phmc.hmc(init_tree, init_branch, (pden,1), data, 100, 0.001, 100,
                         subModel='JC', surrogate=True, burnin_frac=0.2, delta=0.002,
                         adap_stepsz_rate = 0.4, monitor_event=True, printfreq=50)
# Out:
# NNI attempts: 26
# Ref attempts: 40
# 1 iteration: current Loglikelihood = -44027.4111278
# NNI attempts: 22
# Ref attempts: 35
# 2 iteration: current Loglikelihood = -42073.5146223
# NNI attempts: 24
# Ref attempts: 34
# 3 iteration: current Loglikelihood = -40971.9749274
# NNI attempts: 14
# Ref attempts: 22
# 4 iteration: current Loglikelihood = -40971.9749274
# NNI attempts: 3
# Ref attempts: 6
# 5 iteration: current Loglikelihood = -40889.3439994
# NNI attempts: 40
# Ref attempts: 54
# 6 iteration: current Loglikelihood = -39609.2391785
# NNI attempts: 14
# Ref attempts: 22
# 7 iteration: current Loglikelihood = -38486.6886136
# NNI attempts: 2
# Ref attempts: 2
# 8 iteration: current Loglikelihood = -38089.2949076
# NNI attempts: 4
# Ref attempts: 4
# 9 iteration: current Loglikelihood = -37905.306207
# NNI attempts: 30
# Ref attempts: 36
# 10 iteration: current Loglikelihood = -37452.0182803
# NNI attempts: 37
# Ref attempts: 45
# 11 iteration: current Loglikelihood = -36854.1139226
# NNI attempts: 2
# Ref attempts: 2
# 12 iteration: current Loglikelihood = -36845.1234462
# NNI attempts: 3
# Ref attempts: 3
# 13 iteration: current Loglikelihood = -36778.3045256
# NNI attempts: 15
# Ref attempts: 20
# 14 iteration: current Loglikelihood = -36462.4283861
# NNI attempts: 25
# Ref attempts: 37
# 15 iteration: current Loglikelihood = -36339.8039165
# NNI attempts: 20
# Ref attempts: 25
# 16 iteration: current Loglikelihood = -36305.7450579
# NNI attempts: 3
# Ref attempts: 3
# 17 iteration: current Loglikelihood = -36278.2714859
# NNI attempts: 9
# Ref attempts: 12
# 18 iteration: current Loglikelihood = -36211.8016713
# NNI attempts: 13
# Ref attempts: 17
# 19 iteration: current Loglikelihood = -36172.3286665
# NNI attempts: 8
# Ref attempts: 9
# 20 iteration: current Loglikelihood = -36170.1083585
# NNI attempts: 8
# Ref attempts: 11
# 21 iteration: current Loglikelihood = -36165.335237
# NNI attempts: 3
# Ref attempts: 7
# 22 iteration: current Loglikelihood = -36157.62683
# NNI attempts: 9
# Ref attempts: 17
# 23 iteration: current Loglikelihood = -36164.9553194
# NNI attempts: 6
# Ref attempts: 8
# 24 iteration: current Loglikelihood = -36162.5924484
# NNI attempts: 20
# Ref attempts: 24
# 25 iteration: current Loglikelihood = -36162.5924484
# NNI attempts: 13
# Ref attempts: 20
# 26 iteration: current Loglikelihood = -36168.6575627
# NNI attempts: 15
# Ref attempts: 19
# 27 iteration: current Loglikelihood = -36165.7262833
# NNI attempts: 12
# Ref attempts: 15
# 28 iteration: current Loglikelihood = -36172.1696968
# NNI attempts: 17
# Ref attempts: 24
# 29 iteration: current Loglikelihood = -36167.6474714
# NNI attempts: 15
# Ref attempts: 20
# 30 iteration: current Loglikelihood = -36162.5235531
# NNI attempts: 8
# Ref attempts: 9
# 31 iteration: current Loglikelihood = -36160.2283547
# NNI attempts: 7
# Ref attempts: 8
# 32 iteration: current Loglikelihood = -36156.678855
# NNI attempts: 10
# Ref attempts: 16
# 33 iteration: current Loglikelihood = -36156.8725316
# NNI attempts: 11
# Ref attempts: 13
# 34 iteration: current Loglikelihood = -36155.1973996
# NNI attempts: 10
# Ref attempts: 14
# 35 iteration: current Loglikelihood = -36159.6634045
# NNI attempts: 13
# Ref attempts: 20
# 36 iteration: current Loglikelihood = -36159.6634045
# NNI attempts: 1
# Ref attempts: 1
# 37 iteration: current Loglikelihood = -36162.5351835
# NNI attempts: 4
# Ref attempts: 5
# 38 iteration: current Loglikelihood = -36158.6074599
# NNI attempts: 4
# Ref attempts: 9
# 39 iteration: current Loglikelihood = -36158.8455483
# NNI attempts: 20
# Ref attempts: 22
# 40 iteration: current Loglikelihood = -36166.372687
# NNI attempts: 1
# Ref attempts: 1
# 41 iteration: current Loglikelihood = -36159.4346751
# NNI attempts: 7
# Ref attempts: 9
# 42 iteration: current Loglikelihood = -36167.8684537
# NNI attempts: 13
# Ref attempts: 20
# 43 iteration: current Loglikelihood = -36156.3914181
# NNI attempts: 4
# Ref attempts: 8
# 44 iteration: current Loglikelihood = -36158.2952299
# NNI attempts: 20
# Ref attempts: 25
# 45 iteration: current Loglikelihood = -36166.7540689
# NNI attempts: 20
# Ref attempts: 26
# 46 iteration: current Loglikelihood = -36163.9748376
# NNI attempts: 4
# Ref attempts: 9
# 47 iteration: current Loglikelihood = -36163.3663438
# NNI attempts: 8
# Ref attempts: 9
# 48 iteration: current Loglikelihood = -36156.1371364
# NNI attempts: 6
# Ref attempts: 7
# 49 iteration: current Loglikelihood = -36163.952079
# NNI attempts: 3
# Ref attempts: 4
# 50 iteration: current Loglikelihood = -36171.7357132
# 50 iterations completed; acceptance rate: 0.94
# NNI attempts: 3
# Ref attempts: 3
# 51 iteration: current Loglikelihood = -36167.742994
# NNI attempts: 5
# Ref attempts: 6
# 52 iteration: current Loglikelihood = -36162.9365593
# NNI attempts: 0
# Ref attempts: 0
# 53 iteration: current Loglikelihood = -36162.9365593
# NNI attempts: 9
# Ref attempts: 12
# 54 iteration: current Loglikelihood = -36164.0641222
# NNI attempts: 1
# Ref attempts: 1
# 55 iteration: current Loglikelihood = -36164.0641222
# NNI attempts: 1
# Ref attempts: 2
# 56 iteration: current Loglikelihood = -36156.5513135
# NNI attempts: 1
# Ref attempts: 4
# 57 iteration: current Loglikelihood = -36155.454764
# NNI attempts: 2
# Ref attempts: 4
# 58 iteration: current Loglikelihood = -36161.1886273
# NNI attempts: 17
# Ref attempts: 25
# 59 iteration: current Loglikelihood = -36163.1230185
# NNI attempts: 13
# Ref attempts: 17
# 60 iteration: current Loglikelihood = -36163.1230185
# NNI attempts: 9
# Ref attempts: 10
# 61 iteration: current Loglikelihood = -36177.4371435
# NNI attempts: 27
# Ref attempts: 30
# 62 iteration: current Loglikelihood = -36165.3207299
# NNI attempts: 15
# Ref attempts: 19
# 63 iteration: current Loglikelihood = -36162.6883217
# NNI attempts: 8
# Ref attempts: 11
# 64 iteration: current Loglikelihood = -36158.2696814
# NNI attempts: 4
# Ref attempts: 6
# 65 iteration: current Loglikelihood = -36158.2665693
# NNI attempts: 10
# Ref attempts: 13
# 66 iteration: current Loglikelihood = -36163.429642
# NNI attempts: 21
# Ref attempts: 29
# 67 iteration: current Loglikelihood = -36160.1268873
# NNI attempts: 15
# Ref attempts: 19
# 68 iteration: current Loglikelihood = -36165.0983316
# NNI attempts: 10
# Ref attempts: 13
# 69 iteration: current Loglikelihood = -36165.0983316
# NNI attempts: 4
# Ref attempts: 6
# 70 iteration: current Loglikelihood = -36169.5495187
# NNI attempts: 8
# Ref attempts: 16
# 71 iteration: current Loglikelihood = -36168.7567436
# NNI attempts: 2
# Ref attempts: 3
# 72 iteration: current Loglikelihood = -36166.8965096
# NNI attempts: 0
# Ref attempts: 0
# 73 iteration: current Loglikelihood = -36169.9200825
# NNI attempts: 19
# Ref attempts: 23
# 74 iteration: current Loglikelihood = -36165.1785418
# NNI attempts: 21
# Ref attempts: 28
# 75 iteration: current Loglikelihood = -36167.2488259
# NNI attempts: 2
# Ref attempts: 7
# 76 iteration: current Loglikelihood = -36150.9876072
# NNI attempts: 20
# Ref attempts: 27
# 77 iteration: current Loglikelihood = -36155.9167311
# NNI attempts: 25
# Ref attempts: 30
# 78 iteration: current Loglikelihood = -36160.4783937
# NNI attempts: 13
# Ref attempts: 16
# 79 iteration: current Loglikelihood = -36167.085523
# NNI attempts: 10
# Ref attempts: 14
# 80 iteration: current Loglikelihood = -36156.1040651
# NNI attempts: 16
# Ref attempts: 19
# 81 iteration: current Loglikelihood = -36157.5249484
# NNI attempts: 18
# Ref attempts: 23
# 82 iteration: current Loglikelihood = -36162.0800704
# NNI attempts: 11
# Ref attempts: 15
# 83 iteration: current Loglikelihood = -36166.1108549
# NNI attempts: 5
# Ref attempts: 9
# 84 iteration: current Loglikelihood = -36177.6316787
# NNI attempts: 12
# Ref attempts: 16
# 85 iteration: current Loglikelihood = -36184.3302612
# NNI attempts: 3
# Ref attempts: 4
# 86 iteration: current Loglikelihood = -36165.5032208
# NNI attempts: 22
# Ref attempts: 30
# 87 iteration: current Loglikelihood = -36171.6767048
# NNI attempts: 12
# Ref attempts: 18
# 88 iteration: current Loglikelihood = -36171.6767048
# NNI attempts: 3
# Ref attempts: 3
# 89 iteration: current Loglikelihood = -36173.8161216
# NNI attempts: 17
# Ref attempts: 26
# 90 iteration: current Loglikelihood = -36173.8161216
# NNI attempts: 2
# Ref attempts: 5
# 91 iteration: current Loglikelihood = -36150.0987888
# NNI attempts: 14
# Ref attempts: 20
# 92 iteration: current Loglikelihood = -36150.0987888
# NNI attempts: 2
# Ref attempts: 5
# 93 iteration: current Loglikelihood = -36155.9601458
# NNI attempts: 5
# Ref attempts: 15
# 94 iteration: current Loglikelihood = -36162.6163254
# NNI attempts: 0
# Ref attempts: 0
# 95 iteration: current Loglikelihood = -36163.1283129
# NNI attempts: 17
# Ref attempts: 21
# 96 iteration: current Loglikelihood = -36175.1767477
# NNI attempts: 8
# Ref attempts: 10
# 97 iteration: current Loglikelihood = -36163.2743979
# NNI attempts: 9
# Ref attempts: 14
# 98 iteration: current Loglikelihood = -36159.8767873
# NNI attempts: 8
# Ref attempts: 12
# 99 iteration: current Loglikelihood = -36156.8716598
# NNI attempts: 5
# Ref attempts: 5
# 100 iteration: current Loglikelihood = -36152.8837841
# 100 iterations completed; acceptance rate: 0.86
# Overall acceptance rate: 0.8875
