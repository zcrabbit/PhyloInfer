# %% [markdown]
# # An example on simulated data

# %%
# load modules
import phyloinfer as pinf
import numpy as np

# %%
# simulate Data
pden = np.array([.25,.25,.25,.25])
kappa = 2

# decompose the rate matrix (JC model)
D, U, U_inv, rate_matrix = pinf.rateM.decompHKY(pden, kappa)

# sample a random tree from the prior
ntips = 50
true_tree = pinf.tree.create(ntips, branch='random')

data = pinf.data.treeSimu(true_tree, D, U, U_inv, pden, 1000)

# %%
# you may want to take a look of the negative log-posterior and log-likelihood of the true tree
L = pinf.Loglikelihood.initialCLV(data)
true_branch = pinf.branch.get(true_tree)
print "The negative log-posterior of the true tree: {}".format(pinf.Logposterior.Logpost(true_tree, true_branch, D, U, U_inv, pden, L))
print "The log-likelihood of the true tree: {}".format(pinf.Loglikelihood.phyloLoglikelihood(true_tree, true_branch, D, U, U_inv, pden, L))
# Out:
# The negative log-posterior of the true tree: 33850.5063637
# The log-likelihood of the true tree: -33976.8148334

# %%
# sample a starting tree from the prior
init_true = pinf.tree.create(ntips, branch='random')

# %%
# you may also want to take a look of the negative log-posterior and log-likelihood of the initial tree
init_branch = pinf.branch.get(init_tree)
print "The negative log-posterior of the init tree: {}".format(pinf.Logposterior.Logpost(init_tree, init_branch, D, U, U_inv, pden, L))
print "The log-likelihood of the init tree: {}".format(pinf.Loglikelihood.phyloLoglikelihood(init_tree, init_branch, D, U, U_inv, pden, L))
# Out:
# The negative log-posterior of the init tree: 46822.0182937
# The log-likelihood of the init tree: -46954.699082

# %%
# now run ppHMC to sample from the posterior
samp_res = pinf.phmc.hmc(init_tree, init_branch, (pden, kappa), data, 100, 0.001, 100,
                         subModel='HKY', surrogate=True, burnin_frac=0.2, delta=0.002,
                         adap_stepsz_rate = 0.4, monitor_event=True, printfreq=50)
# Out:
# NNI attempts: 0
# Ref attempts: 0
# 1 iteration: current Loglikelihood = -39379.8362746
# NNI attempts: 26
# Ref attempts: 35
# 2 iteration: current Loglikelihood = -35818.5392191
# NNI attempts: 10
# Ref attempts: 17
# 3 iteration: current Loglikelihood = -35021.8197457
# NNI attempts: 10
# Ref attempts: 16
# 4 iteration: current Loglikelihood = -34538.3769755
# NNI attempts: 33
# Ref attempts: 45
# 5 iteration: current Loglikelihood = -34538.3769755
# NNI attempts: 46
# Ref attempts: 70
# 6 iteration: current Loglikelihood = -34538.3769755
# NNI attempts: 34
# Ref attempts: 51
# 7 iteration: current Loglikelihood = -34538.3769755
# NNI attempts: 10
# Ref attempts: 14
# 8 iteration: current Loglikelihood = -34194.7397619
# NNI attempts: 39
# Ref attempts: 73
# 9 iteration: current Loglikelihood = -34194.7397619
# NNI attempts: 13
# Ref attempts: 22
# 10 iteration: current Loglikelihood = -34194.7397619
# NNI attempts: 19
# Ref attempts: 38
# 11 iteration: current Loglikelihood = -34194.7397619
# NNI attempts: 44
# Ref attempts: 78
# 12 iteration: current Loglikelihood = -33721.7817117
# NNI attempts: 30
# Ref attempts: 58
# 13 iteration: current Loglikelihood = -33187.4324906
# NNI attempts: 8
# Ref attempts: 13
# 14 iteration: current Loglikelihood = -32856.2259547
# NNI attempts: 40
# Ref attempts: 71
# 15 iteration: current Loglikelihood = -32436.6170462
# NNI attempts: 22
# Ref attempts: 44
# 16 iteration: current Loglikelihood = -32436.6170462
# NNI attempts: 3
# Ref attempts: 9
# 17 iteration: current Loglikelihood = -32258.5152475
# NNI attempts: 24
# Ref attempts: 54
# 18 iteration: current Loglikelihood = -32033.1167146
# NNI attempts: 19
# Ref attempts: 47
# 19 iteration: current Loglikelihood = -31677.5318824
# NNI attempts: 15
# Ref attempts: 41
# 20 iteration: current Loglikelihood = -31677.5318824
# NNI attempts: 36
# Ref attempts: 76
# 21 iteration: current Loglikelihood = -31365.2969199
# NNI attempts: 5
# Ref attempts: 11
# 22 iteration: current Loglikelihood = -31365.2969199
# NNI attempts: 1
# Ref attempts: 5
# 23 iteration: current Loglikelihood = -31334.3684476
# NNI attempts: 18
# Ref attempts: 44
# 24 iteration: current Loglikelihood = -31334.3684476
# NNI attempts: 19
# Ref attempts: 46
# 25 iteration: current Loglikelihood = -31249.7012491
# NNI attempts: 15
# Ref attempts: 53
# 26 iteration: current Loglikelihood = -31249.7012491
# NNI attempts: 16
# Ref attempts: 42
# 27 iteration: current Loglikelihood = -31224.4837888
# NNI attempts: 9
# Ref attempts: 27
# 28 iteration: current Loglikelihood = -31147.930989
# NNI attempts: 5
# Ref attempts: 15
# 29 iteration: current Loglikelihood = -31091.8337534
# NNI attempts: 3
# Ref attempts: 15
# 30 iteration: current Loglikelihood = -31082.6160985
# NNI attempts: 4
# Ref attempts: 26
# 31 iteration: current Loglikelihood = -31089.5237872
# NNI attempts: 6
# Ref attempts: 34
# 32 iteration: current Loglikelihood = -31086.4941122
# NNI attempts: 4
# Ref attempts: 19
# 33 iteration: current Loglikelihood = -31086.4941122
# NNI attempts: 1
# Ref attempts: 3
# 34 iteration: current Loglikelihood = -31087.1993395
# NNI attempts: 7
# Ref attempts: 26
# 35 iteration: current Loglikelihood = -31083.912103
# NNI attempts: 4
# Ref attempts: 20
# 36 iteration: current Loglikelihood = -31093.133721
# NNI attempts: 4
# Ref attempts: 29
# 37 iteration: current Loglikelihood = -31083.3944401
# NNI attempts: 1
# Ref attempts: 7
# 38 iteration: current Loglikelihood = -31083.3944401
# NNI attempts: 6
# Ref attempts: 42
# 39 iteration: current Loglikelihood = -31092.7218363
# NNI attempts: 0
# Ref attempts: 30
# 40 iteration: current Loglikelihood = -31089.5724927
# NNI attempts: 2
# Ref attempts: 20
# 41 iteration: current Loglikelihood = -31084.070041
# NNI attempts: 7
# Ref attempts: 40
# 42 iteration: current Loglikelihood = -31081.3833791
# NNI attempts: 0
# Ref attempts: 3
# 43 iteration: current Loglikelihood = -31084.9105672
# NNI attempts: 0
# Ref attempts: 3
# 44 iteration: current Loglikelihood = -31084.8112612
# NNI attempts: 0
# Ref attempts: 28
# 45 iteration: current Loglikelihood = -31080.840078
# NNI attempts: 10
# Ref attempts: 38
# 46 iteration: current Loglikelihood = -31095.2563411
# NNI attempts: 1
# Ref attempts: 2
# 47 iteration: current Loglikelihood = -31095.2563411
# NNI attempts: 3
# Ref attempts: 12
# 48 iteration: current Loglikelihood = -31082.5434444
# NNI attempts: 3
# Ref attempts: 20
# 49 iteration: current Loglikelihood = -31082.5434444
# NNI attempts: 0
# Ref attempts: 24
# 50 iteration: current Loglikelihood = -31081.4326171
# 50 iterations completed; acceptance rate: 0.7
# NNI attempts: 0
# Ref attempts: 55
# 51 iteration: current Loglikelihood = -31081.4326171
# NNI attempts: 2
# Ref attempts: 18
# 52 iteration: current Loglikelihood = -31083.8424008
# NNI attempts: 1
# Ref attempts: 12
# 53 iteration: current Loglikelihood = -31088.8307046
# NNI attempts: 6
# Ref attempts: 56
# 54 iteration: current Loglikelihood = -31094.1857156
# NNI attempts: 5
# Ref attempts: 39
# 55 iteration: current Loglikelihood = -31099.8353895
# NNI attempts: 7
# Ref attempts: 27
# 56 iteration: current Loglikelihood = -31098.2229722
# NNI attempts: 7
# Ref attempts: 45
# 57 iteration: current Loglikelihood = -31078.3102294
# NNI attempts: 0
# Ref attempts: 16
# 58 iteration: current Loglikelihood = -31083.8288024
# NNI attempts: 2
# Ref attempts: 11
# 59 iteration: current Loglikelihood = -31074.1375018
# NNI attempts: 4
# Ref attempts: 26
# 60 iteration: current Loglikelihood = -31077.3148714
# NNI attempts: 12
# Ref attempts: 59
# 61 iteration: current Loglikelihood = -31081.3315737
# NNI attempts: 8
# Ref attempts: 46
# 62 iteration: current Loglikelihood = -31064.1407364
# NNI attempts: 12
# Ref attempts: 43
# 63 iteration: current Loglikelihood = -31015.5458025
# NNI attempts: 7
# Ref attempts: 58
# 64 iteration: current Loglikelihood = -30697.4377149
# NNI attempts: 1
# Ref attempts: 8
# 65 iteration: current Loglikelihood = -30687.4471296
# NNI attempts: 7
# Ref attempts: 49
# 66 iteration: current Loglikelihood = -30687.4471296
# NNI attempts: 5
# Ref attempts: 41
# 67 iteration: current Loglikelihood = -30626.0982663
# NNI attempts: 6
# Ref attempts: 45
# 68 iteration: current Loglikelihood = -30626.0982663
# NNI attempts: 2
# Ref attempts: 50
# 69 iteration: current Loglikelihood = -30626.0982663
# NNI attempts: 0
# Ref attempts: 24
# 70 iteration: current Loglikelihood = -30582.3754342
# NNI attempts: 1
# Ref attempts: 37
# 71 iteration: current Loglikelihood = -30578.1793404
# NNI attempts: 0
# Ref attempts: 0
# 72 iteration: current Loglikelihood = -30576.0892333
# NNI attempts: 0
# Ref attempts: 28
# 73 iteration: current Loglikelihood = -30576.0892333
# NNI attempts: 0
# Ref attempts: 27
# 74 iteration: current Loglikelihood = -30571.7723137
# NNI attempts: 6
# Ref attempts: 33
# 75 iteration: current Loglikelihood = -30571.7723137
# NNI attempts: 3
# Ref attempts: 35
# 76 iteration: current Loglikelihood = -30578.7790795
# NNI attempts: 4
# Ref attempts: 15
# 77 iteration: current Loglikelihood = -30578.629234
# NNI attempts: 4
# Ref attempts: 21
# 78 iteration: current Loglikelihood = -30581.2835944
# NNI attempts: 2
# Ref attempts: 20
# 79 iteration: current Loglikelihood = -30573.4500827
# NNI attempts: 0
# Ref attempts: 4
# 80 iteration: current Loglikelihood = -30573.4500827
# NNI attempts: 1
# Ref attempts: 42
# 81 iteration: current Loglikelihood = -30569.2718593
# NNI attempts: 3
# Ref attempts: 19
# 82 iteration: current Loglikelihood = -30581.0631344
# NNI attempts: 10
# Ref attempts: 42
# 83 iteration: current Loglikelihood = -30577.6585967
# NNI attempts: 2
# Ref attempts: 7
# 84 iteration: current Loglikelihood = -30577.6585967
# NNI attempts: 7
# Ref attempts: 36
# 85 iteration: current Loglikelihood = -30577.6585967
# NNI attempts: 14
# Ref attempts: 58
# 86 iteration: current Loglikelihood = -30575.8966113
# NNI attempts: 2
# Ref attempts: 11
# 87 iteration: current Loglikelihood = -30571.2656051
# NNI attempts: 11
# Ref attempts: 61
# 88 iteration: current Loglikelihood = -30575.8115509
# NNI attempts: 8
# Ref attempts: 43
# 89 iteration: current Loglikelihood = -30575.8115509
# NNI attempts: 5
# Ref attempts: 21
# 90 iteration: current Loglikelihood = -30575.8115509
# NNI attempts: 6
# Ref attempts: 25
# 91 iteration: current Loglikelihood = -30574.1622948
# NNI attempts: 2
# Ref attempts: 19
# 92 iteration: current Loglikelihood = -30574.1622948
# NNI attempts: 1
# Ref attempts: 11
# 93 iteration: current Loglikelihood = -30574.7837633
# NNI attempts: 8
# Ref attempts: 41
# 94 iteration: current Loglikelihood = -30567.4204662
# NNI attempts: 6
# Ref attempts: 34
# 95 iteration: current Loglikelihood = -30571.9993383
# NNI attempts: 1
# Ref attempts: 5
# 96 iteration: current Loglikelihood = -30581.8394513
# NNI attempts: 9
# Ref attempts: 43
# 97 iteration: current Loglikelihood = -30587.0151459
# NNI attempts: 7
# Ref attempts: 31
# 98 iteration: current Loglikelihood = -30579.440763
# NNI attempts: 1
# Ref attempts: 6
# 99 iteration: current Loglikelihood = -30579.440763
# NNI attempts: 3
# Ref attempts: 17
# 100 iteration: current Loglikelihood = -30583.0194229
# 100 iterations completed; acceptance rate: 0.74
# Overall acceptance rate: 0.75

# %%
D
# Out:
# array([ -2.22044605e-16,  -1.50000000e+00,  -1.00000000e+00,
#         -1.50000000e+00])
